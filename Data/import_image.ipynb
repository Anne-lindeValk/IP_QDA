# %% [markdown]
# Splitting channels of images using CV

# %%
#import library
import numpy as np
import cv2 as cv

# %%
# %pwd
# Out:
# '/Users/anne-lindevalk/M25-26/P6_IP_QDA/project/IP_QDA/Data'

# %%
#read image
img = cv.imread('lig_2-13_24h/250221_2-13_24h_g1.tif', cv.IMREAD_UNCHANGED)
assert img is not None, "file could not be read, check with os.path.exists()"
# Out:
# [ WARN:0@168.239] global loadsave.cpp:278 findDecoder imread_('lig_2-13_24h/250221_2-13_24h_g1.tif'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 #read image
#       2 img = cv.imread('lig_2-13_24h/250221_2-13_24h_g1.tif', cv.IMREAD_UNCHANGED)
# ----> 3 assert img is not None, "file could not be read, check with os.path.exists()"
#
# AssertionError: file could not be read, check with os.path.exists()
