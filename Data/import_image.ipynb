# %% [markdown]
# Splitting channels of images using CV

# %%
#import library
import numpy as np
from matplotlib import pyplot as plt
# from skimage.io import imread
import tifffile as tiff

# %%
# %pwd
# Out:
# '/Users/anne-lindevalk/M25-26/P6_IP_QDA/project/IP_QDA/Data'

# %%
img2 = tiff.imread('lif_2-13_24h/250221_2-13_24h_g1.tif')
img2.shape
# Out:
# (23, 4, 512, 512)
